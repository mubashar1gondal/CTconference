# %% [markdown]
# Simply put, your main objective for this coding challenge is to send an API request to a server, get the data, then build a solution after getting the data.

# %% [markdown]
# Here's the server address: https://ct-mock-tech-assessment.herokuapp.com/<br>

# %% [markdown]
# The data is a collection of partners who need to attend meetings within their respective countries. For each partner you will find first and last names, email addresses, country locations and dates of availability.

# %% [markdown]
# Your job is to  build an invitation list based on the data. An example solution would look like the following. Keep in mind this is an example and not the real solution.

# %% [markdown]
# <strong>THE FOLLOWING IS `ONLY` AN EXAMPLE.</strong>

# %%
# [   {   'attendeeCount': 12,
#         'attendees': [   'rketring@codingtemple.com',
#                          'mlacau@codingtemple.com',
#                          'eomersa@codingtemple.com',
#                          'ssheahan@codingtemple.com',
#                          'msoult@codingtemple.com',
#                          'bwatton@codingtemple.com',
#                          'afernadez@codingtemple.com',
#                          'mmottern@codingtemple.com',
#                          'pdougherty@codingtemple.com',
#                          'sbeemon@codingtemple.com',
#                          'mvirgel@codingtemple.com',
#                          'hpolitte@codingtemple.com'],
#         'name': 'United States',
#         'startDate': '2017-06-01'},
#     {   'attendeeCount': 12,
#         'attendees': [   'sterrence@codingtemple.com',
#                          'dpatnode@codingtemple.com',
#                          'pbertog@codingtemple.com',
#                          'rguldemond@codingtemple.com',
#                          'rfarlee@codingtemple.com',
#                          'mclawson@codingtemple.com',
#                          'mbottenfield@codingtemple.com',
#                          'akulju@codingtemple.com',
#                          'cscoby@codingtemple.com',
#                          'dsiebenthal@codingtemple.com',
#                          'mcrossen@codingtemple.com',
#                          'mkimble@codingtemple.com'],
#         'name': 'Ireland',
#         'startDate': '2017-06-04'},
#     {   'attendeeCount': 14,
#         'attendees': [   'oduttinger@codingtemple.com',
#                          'tzavesky@codingtemple.com',
#                          'alyme@codingtemple.com',
#                          'aferkovich@codingtemple.com',
#                          'cbrookhouse@codingtemple.com',
#                          'mselk@codingtemple.com',
#                          'amacneil@codingtemple.com',
#                          'jplants@codingtemple.com',
#                          'devora@codingtemple.com',
#                          'bcustis@codingtemple.com',
#                          'labbot@codingtemple.com',
#                          'civery@codingtemple.com',
#                          'jfavieri@codingtemple.com',
#                          'anickless@codingtemple.com'],
#         'name': 'Spain',
#         'startDate': '2017-05-03'},
#     {   'attendeeCount': 3,
#         'attendees': [   'ltoepperwein@codingtemple.com',
#                          'olavine@codingtemple.com',
#                          'ksinitiere@codingtemple.com'],
#         'name': 'Mexico',
#         'startDate': '2017-05-03'},
#     {   'attendeeCount': 3,
#         'attendees': [   'abending@codingtemple.com',
#                          'agewant@codingtemple.com',
#                          'mboyarski@codingtemple.com'],
#         'name': 'Canada',
#         'startDate': '2017-07-02'},
#     {   'attendeeCount': None,
#         'attendees': [],
#         'name': 'Singapore',
#         'startDate': '2017-06-15'},
#     {   'attendeeCount': None,
#         'attendees': [],
#         'name': 'Japan',
#         'startDate': '2017-06-27'},
#     {   'attendeeCount': 16,
#         'attendees': [   'arosentrater@codingtemple.com',
#                          'jgoettsche@codingtemple.com',
#                          'nbehal@codingtemple.com',
#                          'bkilcher@codingtemple.com',
#                          'ostutler@codingtemple.com',
#                          'emaohu@codingtemple.com',
#                          'jbattistoni@codingtemple.com',
#                          'ccoryea@codingtemple.com',
#                          'gcintron@codingtemple.com',
#                          'scorlett@codingtemple.com',
#                          'dallocca@codingtemple.com',
#                          'dneedler@codingtemple.com',
#                          'lsachez@codingtemple.com',
#                          'sszabo@codingtemple.com',
#                          'smaleck@codingtemple.com',
#                          'jholtrop@codingtemple.com'],
#         'name': 'United Kingdom',
#         'startDate': '2017-06-05'},
#     {   'attendeeCount': 5,
#         'attendees': [   'bdurke@codingtemple.com',
#                          'jtopp@codingtemple.com',
#                          'tpinela@codingtemple.com',
#                          'jdefore@codingtemple.com',
#                          'jmacareno@codingtemple.com'],
#         'name': 'France',
#         'startDate': '2017-06-18'}]

# %% [markdown]
# For each partner, you need to categorize them according to the country in which they must attend the meeting. Find a way to determine which availability dates work best for everyone in EACH country. If a date doesn't work for a specific partner, they simply will not be able to attend the meeting.
#
# <strong>The kicker</strong>: this meeting will last a total of two days. Because of this, you must find a RANGE of two dates that work best for everyone. For whichever two days work the best, only display the first date everyone can start.
#
# <strong>When you've finished, send a POST request to the same API (Google how to do this!!!). If you get a server response code of 200, you were successful in building your solution. Otherwise, hit the drawing board and try again!</strong>

# %%
#this area just for brainstorming

import requests as r
from collections import ChainMap

data =  r.get('https://ct-mock-tech-assessment.herokuapp.com/').json()
x = data['partners']

USName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Dates':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['availableDates'][0]  == '2017-05-19' and x['country'] == 'United States']

# %%
import requests as r
d =  r.get('https://ct-mock-tech-assessment.herokuapp.com/').json()
USName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['availableDates'][0]  == '2017-05-19' and x['country'] == 'United States']

IRName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'Ireland' and x['availableDates'][0] == '2017-05-28']

SPName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'Spain' and x['availableDates'][0] == '2017-04-15']

MXName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'Mexico' and x['availableDates'][0] == '2017-04-17']

CNName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'Canada' and x['availableDates'][0] == '2017-06-23']

SNName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'Singapore' and x['availableDates'][0] == '2017-06-03']

JPName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'Japan' and x['availableDates'][0] == '2017-06-09']

UKName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'United Kingdom' and x['availableDates'][0] == '2017-06-01']

FRName = [{'Firstname':x['firstName'], 'LastName': x['lastName'], 'Date':x['availableDates'][0], 'Email':x['email']} for x in data['partners'] if x['country'] == 'France' and x['availableDates'][0] == '2017-06-08']


class Conference:
    def __init__(self):
        d = r.get('https://ct-mock-tech-assessment.herokuapp.com/').json()
        self.usa = USName
        self.ireland = IRName
        self.spain = SPName
        self.mexico = MXName
        self.canada = CNName
        self.singapore = SNName
        self.japan = JPName
        self.uk = UKName
        self.france = FRName
        self.US_dict = {
            'USA Attendees': self.usa,
            'Ireland Attendees': self.ireland,
            'Spain Attendees': self.spain,
            'Mexico Attendees': self.mexico,
            'Canada Attendees': self.canada,
            'Singapore Attendees': self.singapore,
            'Japan Attendees': self.japan,
            'United Kindgom Attendees': self.uk,
            'France Attendees': self.france
    }
       
        

p = Conference()
p.US_dict
# Out:
# {'USA Attendees': [{'Firstname': 'Rebbeca',
#    'LastName': 'Ketring',
#    'Date': '2017-05-19',
#    'Email': 'rketring@codingtemple.com'},
#   {'Firstname': 'Britt',
#    'LastName': 'Watton',
#    'Date': '2017-05-19',
#    'Email': 'bwatton@codingtemple.com'},
#   {'Firstname': 'Aaron',
#    'LastName': 'Fernadez',
#    'Date': '2017-05-19',
#    'Email': 'afernadez@codingtemple.com'},
#   {'Firstname': 'Phung',
#    'LastName': 'Dougherty',
#    'Date': '2017-05-19',
#    'Email': 'pdougherty@codingtemple.com'},
#   {'Firstname': 'Nada',
#    'LastName': 'Kobbe',
#    'Date': '2017-05-19',
#    'Email': 'nkobbe@codingtemple.com'}],
#  'Ireland Attendees': [{'Firstname': 'Santos',
#    'LastName': 'Terrence',
#    'Date': '2017-05-28',
#    'Email': 'sterrence@codingtemple.com'},
#   {'Firstname': 'Daniella',
#    'LastName': 'Patnode',
#    'Date': '2017-05-28',
#    'Email': 'dpatnode@codingtemple.com'},
#   {'Firstname': 'Riva',
#    'LastName': 'Guldemond',
#    'Date': '2017-05-28',
#    'Email': 'rguldemond@codingtemple.com'},
#   {'Firstname': 'Marie',
#    'LastName': 'Bottenfield',
#    'Date': '2017-05-28',
#    'Email': 'mbottenfield@codingtemple.com'},
#   {'Firstname': 'Dot',
#    'LastName': 'Siebenthal',
#    'Date': '2017-05-28',
#    'Email': 'dsiebenthal@codingtemple.com'},
#   {'Firstname': 'Marget',
#    'LastName': 'Crossen',
#    'Date': '2017-05-28',
#    'Email': 'mcrossen@codingtemple.com'}],
#  'Spain Attendees': [{'Firstname': 'Obdulia',
#    'LastName': 'Duttinger',
#    'Date': '2017-04-15',
#    'Email': 'oduttinger@codingtemple.com'},
#   {'Firstname': 'Alleen',
#    'LastName': 'Ferkovich',
#    'Date': '2017-04-15',
#    'Email': 'aferkovich@codingtemple.com'},
#   {'Firstname': 'Caprice',
#    'LastName': 'Brookhouse',
#    'Date': '2017-04-15',
#    'Email': 'cbrookhouse@codingtemple.com'},
#   {'Firstname': 'Marcela',
#    'LastName': 'Selk',
#    'Date': '2017-04-15',
#    'Email': 'mselk@codingtemple.com'},
#   {'Firstname': 'Dick',
#    'LastName': 'Evora',
#    'Date': '2017-04-15',
#    'Email': 'devora@codingtemple.com'},
#   {'Firstname': 'Loree',
#    'LastName': 'Abbot',
#    'Date': '2017-04-15',
#    'Email': 'labbot@codingtemple.com'},
#   {'Firstname': 'Camie',
#    'LastName': 'Ivery',
#    'Date': '2017-04-15',
#    'Email': 'civery@codingtemple.com'},
#   {'Firstname': 'Jenee',
#    'LastName': 'Favieri',
#    'Date': '2017-04-15',
#    'Email': 'jfavieri@codingtemple.com'},
#   {'Firstname': 'Sima',
#    'LastName': 'Studniarz',
#    'Date': '2017-04-15',
#    'Email': 'sstudniarz@codingtemple.com'}],
#  'Mexico Attendees': [{'Firstname': 'Sharon',
#    'LastName': 'Brugliera',
#    'Date': '2017-04-17',
#    'Email': 'sbrugliera@codingtemple.com'},
#   {'Firstname': 'Alfonso',
#    'LastName': 'Danza',
#    'Date': '2017-04-17',
#    'Email': 'adanza@codingtemple.com'},
#   {'Firstname': 'Olivia',
#    'LastName': 'Treworgy',
#    'Date': '2017-04-17',
#    'Email': 'otreworgy@codingtemple.com'},
#   {'Firstname': 'Bobbie',
#    'LastName': 'Parmele',
#    'Date': '2017-04-17',
#    'Email': 'bparmele@codingtemple.com'},
#   {'Firstname': 'Artie',
#    'LastName': 'Molinini',
#    'Date': '2017-04-17',
#    'Email': 'amolinini@codingtemple.com'},
#   {'Firstname': 'Florencia',
#    'LastName': 'Maier',
#    'Date': '2017-04-17',
#    'Email': 'fmaier@codingtemple.com'},
#   {'Firstname': 'Paulina',
#    'LastName': 'Strohbehn',
#    'Date': '2017-04-17',
#    'Email': 'pstrohbehn@codingtemple.com'},
#   {'Firstname': 'Celine',
#    'LastName': 'Vipond',
#    'Date': '2017-04-17',
#    'Email': 'cvipond@codingtemple.com'},
#   {'Firstname': 'Billie',
#    'LastName': 'Reatherford',
#    'Date': '2017-04-17',
#    'Email': 'breatherford@codingtemple.com'}],
#  'Canada Attendees': [{'Firstname': 'Randy',
#    'LastName': 'Rojero',
#    'Date': '2017-06-23',
#    'Email': 'rrojero@codingtemple.com'},
#   {'Firstname': 'Natividad',
#    'LastName': 'Shier',
#    'Date': '2017-06-23',
#    'Email': 'nshier@codingtemple.com'},
#   {'Firstname': 'Toccara',
#    'LastName': 'Devoll',
#    'Date': '2017-06-23',
#    'Email': 'tdevoll@codingtemple.com'},
#   {'Firstname': 'Lin',
#    'LastName': 'Gritton',
#    'Date': '2017-06-23',
#    'Email': 'lgritton@codingtemple.com'},
#   {'Firstname': 'Edris',
#    'LastName': 'Lizarrago',
#    'Date': '2017-06-23',
#    'Email': 'elizarrago@codingtemple.com'},
#   {'Firstname': 'Evie',
#    'LastName': 'Hartly',
#    'Date': '2017-06-23',
#    'Email': 'ehartly@codingtemple.com'},
#   {'Firstname': 'Marco',
#    'LastName': 'Hutley',
#    'Date': '2017-06-23',
#    'Email': 'mhutley@codingtemple.com'},
#   {'Firstname': 'Roseline',
#    'LastName': 'Veyna',
#    'Date': '2017-06-23',
#    'Email': 'rveyna@codingtemple.com'},
#   {'Firstname': 'Antwan',
#    'LastName': 'Gewant',
#    'Date': '2017-06-23',
#    'Email': 'agewant@codingtemple.com'},
#   {'Firstname': 'Carol',
#    'LastName': 'Sabori',
#    'Date': '2017-06-23',
#    'Email': 'csabori@codingtemple.com'},
#   {'Firstname': 'Joni',
#    'LastName': 'Trieger',
#    'Date': '2017-06-23',
#    'Email': 'jtrieger@codingtemple.com'},
#   {'Firstname': 'Richard',
#    'LastName': 'Radoslovich',
#    'Date': '2017-06-23',
#    'Email': 'rradoslovich@codingtemple.com'},
#   {'Firstname': 'Markus',
#    'LastName': 'Anglebrandt',
#    'Date': '2017-06-23',
#    'Email': 'manglebrandt@codingtemple.com'}],
#  'Singapore Attendees': [{'Firstname': 'Marjorie',
#    'LastName': 'Skrobacki',
#    'Date': '2017-06-03',
#    'Email': 'mskrobacki@codingtemple.com'},
#   {'Firstname': 'Veta',
#    'LastName': 'Goldhirsh',
#    'Date': '2017-06-03',
#    'Email': 'vgoldhirsh@codingtemple.com'},
#   {'Firstname': 'Jude',
#    'LastName': 'Kuester',
#    'Date': '2017-06-03',
#    'Email': 'jkuester@codingtemple.com'},
#   {'Firstname': 'Patricia',
#    'LastName': 'Rushford',
#    'Date': '2017-06-03',
#    'Email': 'prushford@codingtemple.com'},
#   {'Firstname': 'Jannet',
#    'LastName': 'Novakovich',
#    'Date': '2017-06-03',
#    'Email': 'jnovakovich@codingtemple.com'},
#   {'Firstname': 'Sheron',
#    'LastName': 'Kriger',
#    'Date': '2017-06-03',
#    'Email': 'skriger@codingtemple.com'},
#   {'Firstname': 'Yesenia',
#    'LastName': 'Niedzwiecki',
#    'Date': '2017-06-03',
#    'Email': 'yniedzwiecki@codingtemple.com'},
#   {'Firstname': 'Isa',
#    'LastName': 'Moala',
#    'Date': '2017-06-03',
#    'Email': 'imoala@codingtemple.com'},
#   {'Firstname': 'Robbi',
#    'LastName': 'Dreyfuss',
#    'Date': '2017-06-03',
#    'Email': 'rdreyfuss@codingtemple.com'},
#   {'Firstname': 'Dorine',
#    'LastName': 'Haselhuhn',
#    'Date': '2017-06-03',
#    'Email': 'dhaselhuhn@codingtemple.com'},
#   {'Firstname': 'Harry',
#    'LastName': 'Boles',
#    'Date': '2017-06-03',
#    'Email': 'hboles@codingtemple.com'},
#   {'Firstname': 'Shondra',
#    'LastName': 'Gallardo',
#    'Date': '2017-06-03',
#    'Email': 'sgallardo@codingtemple.com'}],
#  'Japan Attendees': [{'Firstname': 'Kandis',
#    'LastName': 'Birenbaum',
#    'Date': '2017-06-09',
#    'Email': 'kbirenbaum@codingtemple.com'},
#   {'Firstname': 'Sidney',
#    'LastName': 'Mallet',
#    'Date': '2017-06-09',
#    'Email': 'smallet@codingtemple.com'},
#   {'Firstname': 'Orpha',
#    'LastName': 'Blackwelder',
#    'Date': '2017-06-09',
#    'Email': 'oblackwelder@codingtemple.com'},
#   {'Firstname': 'Maren',
#    'LastName': 'Leckband',
#    'Date': '2017-06-09',
#    'Email': 'mleckband@codingtemple.com'},
#   {'Firstname': 'Laurette',
#    'LastName': 'Aubrey',
#    'Date': '2017-06-09',
#    'Email': 'laubrey@codingtemple.com'},
#   {'Firstname': 'Stephania',
#    'LastName': 'Koellmann',
#    'Date': '2017-06-09',
#    'Email': 'skoellmann@codingtemple.com'},
#   {'Firstname': 'Carlos',
#    'LastName': 'Grasso',
#    'Date': '2017-06-09',
#    'Email': 'cgrasso@codingtemple.com'},
#   {'Firstname': 'Mao',
#    'LastName': 'Pittard',
#    'Date': '2017-06-09',
#    'Email': 'mpittard@codingtemple.com'},
#   {'Firstname': 'Chanell',
#    'LastName': 'Kollmorgen',
#    'Date': '2017-06-09',
#    'Email': 'ckollmorgen@codingtemple.com'},
#   {'Firstname': 'Tomas',
#    'LastName': 'House',
#    'Date': '2017-06-09',
#    'Email': 'thouse@codingtemple.com'},
#   {'Firstname': 'Darcel',
#    'LastName': 'Rede',
#    'Date': '2017-06-09',
#    'Email': 'drede@codingtemple.com'},
#   {'Firstname': 'Leatha',
#    'LastName': 'Alway',
#    'Date': '2017-06-09',
#    'Email': 'lalway@codingtemple.com'},
#   {'Firstname': 'Florrie',
#    'LastName': 'Peteet',
#    'Date': '2017-06-09',
#    'Email': 'fpeteet@codingtemple.com'},
#   {'Firstname': 'Lynette',
#    'LastName': 'Nikolas',
#    'Date': '2017-06-09',
#    'Email': 'lnikolas@codingtemple.com'},
#   {'Firstname': 'Vernie',
#    'LastName': 'Cortner',
#    'Date': '2017-06-09',
#    'Email': 'vcortner@codingtemple.com'},
#   {'Firstname': 'Henry',
#    'LastName': 'Vazzana',
#    'Date': '2017-06-09',
#    'Email': 'hvazzana@codingtemple.com'}],
#  'United Kindgom Attendees': [{'Firstname': 'Anisha',
#    'LastName': 'Rosentrater',
#    'Date': '2017-06-01',
#    'Email': 'arosentrater@codingtemple.com'},
#   {'Firstname': 'Jeremy',
#    'LastName': 'Goettsche',
#    'Date': '2017-06-01',
#    'Email': 'jgoettsche@codingtemple.com'},
#   {'Firstname': 'Natosha',
#    'LastName': 'Behal',
#    'Date': '2017-06-01',
#    'Email': 'nbehal@codingtemple.com'},
#   {'Firstname': 'Bennett',
#    'LastName': 'Kilcher',
#    'Date': '2017-06-01',
#    'Email': 'bkilcher@codingtemple.com'},
#   {'Firstname': 'Onita',
#    'LastName': 'Stutler',
#    'Date': '2017-06-01',
#    'Email': 'ostutler@codingtemple.com'},
#   {'Firstname': 'Eleanora',
#    'LastName': 'Maohu',
#    'Date': '2017-06-01',
#    'Email': 'emaohu@codingtemple.com'},
#   {'Firstname': 'Jasper',
#    'LastName': 'Battistoni',
#    'Date': '2017-06-01',
#    'Email': 'jbattistoni@codingtemple.com'},
#   {'Firstname': 'Celine',
#    'LastName': 'Coryea',
#    'Date': '2017-06-01',
#    'Email': 'ccoryea@codingtemple.com'},
#   {'Firstname': 'Genaro',
#    'LastName': 'Cintron',
#    'Date': '2017-06-01',
#    'Email': 'gcintron@codingtemple.com'},
#   {'Firstname': 'Shirleen',
#    'LastName': 'Corlett',
#    'Date': '2017-06-01',
#    'Email': 'scorlett@codingtemple.com'},
#   {'Firstname': 'Dina',
#    'LastName': 'Allocca',
#    'Date': '2017-06-01',
#    'Email': 'dallocca@codingtemple.com'},
#   {'Firstname': 'Deetta',
#    'LastName': 'Needler',
#    'Date': '2017-06-01',
#    'Email': 'dneedler@codingtemple.com'},
#   {'Firstname': 'Linnie',
#    'LastName': 'Sachez',
#    'Date': '2017-06-01',
#    'Email': 'lsachez@codingtemple.com'},
#   {'Firstname': 'Sandy',
#    'LastName': 'Szabo',
#    'Date': '2017-06-01',
#    'Email': 'sszabo@codingtemple.com'},
#   {'Firstname': 'Sherise',
#    'LastName': 'Maleck',
#    'Date': '2017-06-01',
#    'Email': 'smaleck@codingtemple.com'},
#   {'Firstname': 'January',
#    'LastName': 'Holtrop',
#    'Date': '2017-06-01',
#    'Email': 'jholtrop@codingtemple.com'}],
#  'France Attendees': [{'Firstname': 'Ericka',
#    'LastName': 'Fallick',
#    'Date': '2017-06-08',
#    'Email': 'efallick@codingtemple.com'},
#   {'Firstname': 'Vern',
#    'LastName': 'Rindal',
#    'Date': '2017-06-08',
#    'Email': 'vrindal@codingtemple.com'},
#   {'Firstname': 'Julieann',
#    'LastName': 'Effner',
#    'Date': '2017-06-08',
#    'Email': 'jeffner@codingtemple.com'},
#   {'Firstname': 'Carmon',
#    'LastName': 'Sibille',
#    'Date': '2017-06-08',
#    'Email': 'csibille@codingtemple.com'},
#   {'Firstname': 'Amina',
#    'LastName': 'Gimble',
#    'Date': '2017-06-08',
#    'Email': 'agimble@codingtemple.com'},
#   {'Firstname': 'Doretta',
#    'LastName': 'Vosburg',
#    'Date': '2017-06-08',
#    'Email': 'dvosburg@codingtemple.com'}]}
